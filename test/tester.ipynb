# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import pandas as pd

# %%
x = range(100)
y = map(lambda x: math.log(x+1), x)

# %%
plt.plot(x,y)
plt.show()

# %%
df = pd.DataFrame({"x": x, "y": x})

# %%
df.head()
# Out:
#    x  y
# 0  0  0
# 1  1  1
# 2  2  2
# 3  3  3
# 4  4  4

# %%
df
# Out:
#      x   y
# 0    0   0
# 1    1   1
# 2    2   2
# 3    3   3
# 4    4   4
# 5    5   5
# 6    6   6
# 7    7   7
# 8    8   8
# 9    9   9
# 10  10  10
# 11  11  11
# 12  12  12
# 13  13  13
# 14  14  14
# 15  15  15
# 16  16  16
# 17  17  17
# 18  18  18
# 19  19  19
# 20  20  20
# 21  21  21
# 22  22  22
# 23  23  23
# 24  24  24
# 25  25  25
# 26  26  26
# 27  27  27
# 28  28  28
# 29  29  29
# ..  ..  ..
# 70  70  70
# 71  71  71
# 72  72  72
# 73  73  73
# 74  74  74
# 75  75  75
# 76  76  76
# 77  77  77
# 78  78  78
# 79  79  79
# 80  80  80
# 81  81  81
# 82  82  82
# 83  83  83
# 84  84  84
# 85  85  85
# 86  86  86
# 87  87  87
# 88  88  88
# 89  89  89
# 90  90  90
# 91  91  91
# 92  92  92
# 93  93  93
# 94  94  94
# 95  95  95
# 96  96  96
# 97  97  97
# 98  98  98
# 99  99  99
#
# [100 rows x 2 columns]
